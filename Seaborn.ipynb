# %%
import seaborn as sms

# %%
tips=sms.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
#distribution graphs
     #distplot
    #Jointplot
    #pairplot
    #

# %%
sms.distplot(tips['total_bill'])

# %%
sms.jointplot(x='total_bill',y='tip',data=tips,kind='kde',color='violet')

# %%
hex,reg

# %%
sms.pairplot(tips,hue='smoker')

# %%
sms.rugplot(tips['total_bill'])

# %%
sms.barplot(x='day',y='tip',data=tips,hue='sex')

# %%
sms.countplot(tips['smoker'],data=tips,hue='sex')

# %%
sms.boxplot(x=tips['sex'],y=tips['tip'])

# %%
sms.violinplot(x=tips['sex'],y=tips['tip'],split=)

# %%
flight=sms.load_dataset('flights')

# %%
flight.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
import pandas as pd

# %%
p=flight.pivot_table(index='year',columns='month',values='passengers')

# %%
p
# Out:
# month  January  February  March  April  May  June  July  August  September  \
# year
# 1949       112       118    132    129  121   135   148     148        136
# 1950       115       126    141    135  125   149   170     170        158
# 1951       145       150    178    163  172   178   199     199        184
# 1952       171       180    193    181  183   218   230     242        209
# 1953       196       196    236    235  229   243   264     272        237
# 1954       204       188    235    227  234   264   302     293        259
# 1955       242       233    267    269  270   315   364     347        312
# 1956       284       277    317    313  318   374   413     405        355
# 1957       315       301    356    348  355   422   465     467        404
# 1958       340       318    362    348  363   435   491     505        404
# 1959       360       342    406    396  420   472   548     559        463
# ...

# %%
sms.heatmap(p)
