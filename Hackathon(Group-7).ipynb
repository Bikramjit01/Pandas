# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic[['Survived','Embarked']]
# Out:
#      Survived Embarked
# 0           0        S
# 1           1        C
# 2           1        S
# 3           1        S
# 4           0        S
# 5           0        Q
# 6           0        S
# 7           0        S
# 8           1        S
# 9           1        C
# 10          1        S
# 11          1        S
# 12          0        S
# 13          0        S
# 14          0        S
# 15          1        S
# 16          0        Q
# 17          1        S
# 18          0        S
# 19          1        C
# 20          0        S
# 21          1        S
# 22          1        Q
# 23          1        S
# 24          0        S
# 25          1        S
# 26          0        C
# 27          0        S
# 28          1        Q
# 29          0        S
# ..        ...      ...
# 861         0        S
# 862         1        S
# 863         0        S
# 864         0        S
# 865         1        S
# 866         1        C
# 867         0        S
# 868         0        S
# ...

# %%
import seaborn as sms

# %%
sms.barplot(x='Embarked',y='Survived',data=titanic,hue='Sex')

# %%
x=[titanic.groupby('Embarked')]

# %%
x

# %%
x=titanic[titanic['Embarked']=='S'].shape

# %%
class10=(644/889)*100

# %%
y=titanic[titanic['Embarked']=='C'].shape

# %%
class20=(168/889)*100

# %%
class30=(77/889)*100

# %%
u=[class10,class20,class30]

# %%
labels=[class10,class20,class30]
r=titanic['Embarked'].value_counts()
plt.pie(u,labels=r.index,autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x27058ad1cc0>,
# ...
#  [Text(-0.7128398214280038, 0.8377704870586524, 'S'),
#   Text(0.4614522559226597, -0.9985298270476893, 'C'),
#   Text(1.059527609881514, -0.2956370137495749, 'Q')],
#  [Text(-0.38882172077891114, 0.4569657202138104, '72.44%'),
#   Text(0.25170123050326887, -0.5446526329351032, '18.90%'),
#   Text(0.5779241508444621, -0.16125655295431357, '8.66%')])

# %%
z=titanic[titanic['Embarked']=='Q'].shape

# %%
sms.countplot(titanic['Sex'],data=titanic,hue='Survived')

# %%
sms.countplot(titanic['Pclass'],data=titanic,hue='Survived')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
